# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("sales_data.csv")

# %%
df.head()
# Out:
#    Order_ID   Product     Category Region  Sales  Quantity
# 0      1001    Laptop  Electronics  North  55000         2
# 1      1002     Mouse  Electronics  South   1200         5
# 2      1003  Keyboard  Electronics   East   2500         3
# 3      1004     Chair    Furniture   West   7500         2
# 4      1005      Desk    Furniture  North  12000         1

# %%
df.shape
# Out:
# (15, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Order_ID  15 non-null     int64
#  1   Product   15 non-null     object
#  2   Category  15 non-null     object
#  3   Region    15 non-null     object
#  4   Sales     15 non-null     int64
#  5   Quantity  15 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 848.0+ bytes

# %%
df.describe()
# Out:
#           Order_ID         Sales   Quantity
# count    15.000000     15.000000  15.000000
# mean   1008.000000  13406.666667   6.200000
# std       4.472136  19005.843713   7.408489
# min    1001.000000    500.000000   1.000000
# 25%    1004.500000   1100.000000   2.000000
# 50%    1008.000000   7500.000000   2.000000
# 75%    1011.500000  15000.000000   7.500000
# max    1015.000000  60000.000000  25.000000

# %%
category_sales = df.groupby("Category")["Sales"].sum()
category_sales
# Out:
# Category
# Electronics    159700
# Furniture       38500
# Stationery       2900
# Name: Sales, dtype: int64

# %%
category_sales.plot(kind="bar")

plt.title("Total Sales by Category")
plt.xlabel("Category")
plt.ylabel("Sales")
plt.tight_layout()
plt.show()

# %%
region_sales = df.groupby("Region")["Sales"].sum()
region_sales
# Out:
# Region
# East      14300
# North    128000
# South     27800
# West      31000
# Name: Sales, dtype: int64

# %%
region_sales.plot(kind="bar")

plt.title("Total Sales by Region")
plt.xlabel("Region")
plt.ylabel("Sales")
plt.tight_layout()
plt.show()

# %%
electronics = df[df["Category"] == "Electronics"]
electronics
# Out:
#     Order_ID   Product     Category Region  Sales  Quantity
# 0       1001    Laptop  Electronics  North  55000         2
# 1       1002     Mouse  Electronics  South   1200         5
# 2       1003  Keyboard  Electronics   East   2500         3
# 5       1006   Monitor  Electronics  South  18000         2
# 8       1009    Laptop  Electronics  North  60000         2
# 11      1012   Monitor  Electronics   West  20000         2
# 14      1015  Keyboard  Electronics   West   3000         4

# %%
high_sales = df[df["Sales"] > 10000]
high_sales
# Out:
#     Order_ID  Product     Category Region  Sales  Quantity
# 0       1001   Laptop  Electronics  North  55000         2
# 4       1005     Desk    Furniture  North  12000         1
# 5       1006  Monitor  Electronics  South  18000         2
# 8       1009   Laptop  Electronics  North  60000         2
# 10      1011     Desk    Furniture   East  11000         1
# 11      1012  Monitor  Electronics   West  20000         2

# %%
df.loc[0]
# Out:
# Order_ID           1001
# Product          Laptop
# Category    Electronics
# Region            North
# Sales             55000
# Quantity              2
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# Order_ID           1001
# Product          Laptop
# Category    Electronics
# Region            North
# Sales             55000
# Quantity              2
# Name: 0, dtype: object

# %%
df.isna().sum()
# Out:
# Order_ID    0
# Product     0
# Category    0
# Region      0
# Sales       0
# Quantity    0
# dtype: int64

# %%
total_sales = df["Sales"].sum()
total_quantity = df["Quantity"].sum()

print("Total Sales:", total_sales)
print("Total Quantity:", total_quantity)
# Out:
# Total Sales: 201100
# Total Quantity: 93

# %%
product_sales = df.groupby("Product")["Sales"].sum().sort_values(ascending=False)
product_sales
# Out:
# Product
# Laptop      115000
# Monitor      38000
# Desk         23000
# Chair        15500
# Keyboard      5500
# Notebook      1800
# Mouse         1200
# Pen           1100
# Name: Sales, dtype: int64

# %%
import os

os.makedirs("charts", exist_ok=True)
print("charts folder created successfully")
# Out:
# charts folder created successfully

# %%
category_sales.plot(kind="bar")

plt.title("Total Sales by Category")
plt.xlabel("Category")
plt.ylabel("Sales")
plt.tight_layout()

plt.savefig("charts/sales_by_category.png")
plt.show()

# %%
region_sales.plot(kind="bar")

plt.title("Total Sales by Region")
plt.xlabel("Region")
plt.ylabel("Sales")
plt.tight_layout()

plt.savefig("charts/sales_by_region.png")
plt.show()

# %% [markdown]
# ## Key Findings
#
# 1. Electronics generated the highest total sales with ₹159,700.
# 2. Furniture generated ₹38,500 in sales.
# 3. Stationery generated the lowest sales with ₹2,900.
# 4. North was the highest-performing region with ₹128,000 in sales.
# 5. Laptop was the best-selling product by sales value with ₹115,000.
# 6. Total sales across all orders were ₹201,100.
# 7. Total quantity sold was 93 units.
# 8. The regional chart shows that North contributes the majority of total sales.

# %%
import os

print(os.listdir("charts"))
# Out:
# ['sales_by_category.png', 'sales_by_region.png']
